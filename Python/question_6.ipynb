# %%
import pandas as pd

# %%
df = pd.read_excel("question3_data.xlsx")

# %%
# Get all Pokemons whose spawn rate is less than 5%(0.05)
df[df['spawn_chance'] < 0.05]
# Out:
#       id  num        name                                               img
# 1      2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png  \
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 7      8    8   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# ..   ...  ...         ...                                               ...
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
# ...

# %%
# Get all Pokemons that have less than 4 weaknesses
weakness = df['weaknesses'].tolist()

# %%
# Here we can see that list contains strings, inside a string we have list values.
weakness
# Out:
# ["['Fire', 'Ice', 'Flying', 'Psychic']",
#  "['Fire', 'Ice', 'Flying', 'Psychic']",
#  "['Fire', 'Ice', 'Flying', 'Psychic']",
#  "['Water', 'Ground', 'Rock']",
#  "['Water', 'Ground', 'Rock']",
#  "['Water', 'Electric', 'Rock']",
#  "['Electric', 'Grass']",
#  "['Electric', 'Grass']",
#  "['Electric', 'Grass']",
#  "['Fire', 'Flying', 'Rock']",
#  "['Fire', 'Flying', 'Rock']",
#  "['Fire', 'Electric', 'Ice', 'Flying', 'Rock']",
#  "['Fire', 'Flying', 'Psychic', 'Rock']",
#  "['Fire', 'Flying', 'Psychic', 'Rock']",
#  "['Fire', 'Flying', 'Psychic', 'Rock']",
#  "['Electric', 'Rock']",
#  "['Electric', 'Rock']",
#  "['Electric', 'Rock']",
#  "['Fighting']",
#  "['Fighting']",
#  "['Electric', 'Rock']",
#  "['Electric', 'Rock']",
#  "['Ground', 'Psychic']",
#  "['Ground', 'Psychic']",
#  "['Ground']",
#  "['Ground']",
#  "['Water', 'Grass', 'Ice']",
#  "['Water', 'Grass', 'Ice']",
#  "['Ground', 'Psychic']",
#  "['Ground', 'Psychic']",
#  "['Water', 'Ice', 'Ground', 'Psychic']",
# ...

# %%
import ast
# Now we want only list not strings.
weakness_cleaned = [ast.literal_eval(item) for item in weakness]

# %%
weakness_cleaned
# Out:
# [['Fire', 'Ice', 'Flying', 'Psychic'],
#  ['Fire', 'Ice', 'Flying', 'Psychic'],
#  ['Fire', 'Ice', 'Flying', 'Psychic'],
#  ['Water', 'Ground', 'Rock'],
#  ['Water', 'Ground', 'Rock'],
#  ['Water', 'Electric', 'Rock'],
#  ['Electric', 'Grass'],
#  ['Electric', 'Grass'],
#  ['Electric', 'Grass'],
#  ['Fire', 'Flying', 'Rock'],
#  ['Fire', 'Flying', 'Rock'],
#  ['Fire', 'Electric', 'Ice', 'Flying', 'Rock'],
#  ['Fire', 'Flying', 'Psychic', 'Rock'],
#  ['Fire', 'Flying', 'Psychic', 'Rock'],
#  ['Fire', 'Flying', 'Psychic', 'Rock'],
#  ['Electric', 'Rock'],
#  ['Electric', 'Rock'],
#  ['Electric', 'Rock'],
#  ['Fighting'],
#  ['Fighting'],
#  ['Electric', 'Rock'],
#  ['Electric', 'Rock'],
#  ['Ground', 'Psychic'],
#  ['Ground', 'Psychic'],
#  ['Ground'],
#  ['Ground'],
#  ['Water', 'Grass', 'Ice'],
#  ['Water', 'Grass', 'Ice'],
#  ['Ground', 'Psychic'],
#  ['Ground', 'Psychic'],
#  ['Water', 'Ice', 'Ground', 'Psychic'],
#  ['Ground', 'Psychic'],
#  ['Ground', 'Psychic'],
# ...

# %%
df['weakness_cleaned'] = weakness_cleaned

# %%
df.drop('weaknesses',axis=1,inplace=True)

# %%
df['weakness_cleaned']
# Out:
# 0      [Fire, Ice, Flying, Psychic]
# 1      [Fire, Ice, Flying, Psychic]
# 2      [Fire, Ice, Flying, Psychic]
# 3             [Water, Ground, Rock]
# 4             [Water, Ground, Rock]
#                    ...
# 146            [Ice, Dragon, Fairy]
# 147            [Ice, Dragon, Fairy]
# 148      [Ice, Rock, Dragon, Fairy]
# 149              [Bug, Ghost, Dark]
# 150              [Bug, Ghost, Dark]
# Name: weakness_cleaned, Length: 151, dtype: object

# %%
# Filter out pokemon whose weakness is less than 4
df[df['weakness_cleaned'].apply(lambda x: len(x) < 4)]
# Out:
#       id  num        name                                               img
# 3      4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png  \
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 6      7    7    Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 7      8    8   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# ..   ...  ...         ...                                               ...
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 146  147  147     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
# ...

# %%
# Fill NaN value 
df['multipliers'].fillna(0,inplace=True)

# %%
#Get all Pokemons that have no multipliers at all
df[df['multipliers']==0]
# Out:
#       id  num        name                                               img
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png  \
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 8      9    9   Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 11    12   12  Butterfree  http://www.serebii.net/pokemongo/pokemon/012.png
# 14    15   15    Beedrill  http://www.serebii.net/pokemongo/pokemon/015.png
# ..   ...  ...         ...                                               ...
# 144  145  145      Zapdos  http://www.serebii.net/pokemongo/pokemon/145.png
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
# ...

# %%
## Fill NaN value with '0'
df['prev_evolution'].fillna(0,inplace=True)
df['next_evolution'].fillna(0,inplace=True)

# %%
#  Get all Pokemons that do not have more than 2 evolutions
evolution = df[(df['prev_evolution'].apply(lambda x: x!=0)) &
                (df['next_evolution'].apply(lambda x: x!=0))]

# %%
evolution
# Out:
#       id  num        name                                               img
# 1      2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png  \
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 7      8    8   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# 10    11   11     Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 13    14   14      Kakuna  http://www.serebii.net/pokemongo/pokemon/014.png
# 16    17   17   Pidgeotto  http://www.serebii.net/pokemongo/pokemon/017.png
# 29    30   30    Nidorina  http://www.serebii.net/pokemongo/pokemon/030.png
# 32    33   33    Nidorino  http://www.serebii.net/pokemongo/pokemon/033.png
# 43    44   44       Gloom  http://www.serebii.net/pokemongo/pokemon/044.png
# 60    61   61   Poliwhirl  http://www.serebii.net/pokemongo/pokemon/061.png
# 63    64   64     Kadabra  http://www.serebii.net/pokemongo/pokemon/064.png
# ...

# %%
len(evolution)
# Out:
# 16

# %%
df['spawn_time'].isna().sum()
# Out:
# 6

# %%
#Get all Pokemons whose spawn time is less than 300 seconds
df[df['spawn_time']<'05:00']
# Out:
#       id  num       name                                               img
# 6      7    7   Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png  \
# 8      9    9  Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 10    11   11    Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 12    13   13     Weedle  http://www.serebii.net/pokemongo/pokemon/013.png
# 13    14   14     Kakuna  http://www.serebii.net/pokemongo/pokemon/014.png
# ..   ...  ...        ...                                               ...
# 127  128  128     Tauros  http://www.serebii.net/pokemongo/pokemon/128.png
# 129  130  130   Gyarados  http://www.serebii.net/pokemongo/pokemon/130.png
# 134  135  135    Jolteon  http://www.serebii.net/pokemongo/pokemon/135.png
# 136  137  137    Porygon  http://www.serebii.net/pokemongo/pokemon/137.png
# 139  140  140     Kabuto  http://www.serebii.net/pokemongo/pokemon/140.png
#
# ...

# %%
# Get all Pokemon who have more than two types of capabilities
df.head()
# Out:
#    id  num        name                                               img
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png  \
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#                   type  height    weight             candy  candy_count
# 0  ['Grass', 'Poison']  0.71 m    6.9 kg   Bulbasaur Candy         25.0  \
# 1  ['Grass', 'Poison']  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3             ['Fire']  0.61 m    8.5 kg  Charmander Candy         25.0
# 4             ['Fire']  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers
# ...

# %%
types = df['type'].tolist()

# %%
types
# Out:
# ["['Grass', 'Poison']",
#  "['Grass', 'Poison']",
#  "['Grass', 'Poison']",
#  "['Fire']",
#  "['Fire']",
#  "['Fire', 'Flying']",
#  "['Water']",
#  "['Water']",
#  "['Water']",
#  "['Bug']",
#  "['Bug']",
#  "['Bug', 'Flying']",
#  "['Bug', 'Poison']",
#  "['Bug', 'Poison']",
#  "['Bug', 'Poison']",
#  "['Normal', 'Flying']",
#  "['Normal', 'Flying']",
#  "['Normal', 'Flying']",
#  "['Normal']",
#  "['Normal']",
#  "['Normal', 'Flying']",
#  "['Normal', 'Flying']",
#  "['Poison']",
#  "['Poison']",
#  "['Electric']",
#  "['Electric']",
#  "['Ground']",
#  "['Ground']",
#  "['Poison']",
#  "['Poison']",
#  "['Poison', 'Ground']",
#  "['Poison']",
#  "['Poison']",
#  "['Poison', 'Ground']",
#  "['Normal']",
#  "['Normal']",
#  "['Fire']",
#  "['Fire']",
#  "['Normal']",
#  "['Normal']",
#  "['Poison', 'Flying']",
#  "['Poison', 'Flying']",
#  "['Grass', 'Poison']",
#  "['Grass', 'Poison']",
#  "['Grass', 'Poison']",
#  "['Bug', 'Grass']",
#  "['Bug', 'Grass']",
# ...

# %%
types_cleaned = [ast.literal_eval(item) for item in types ]

# %%
df['types_cleaned'] = types_cleaned

# %%
df.drop('type',axis=1,inplace=True)

# %%
# Get all Pokemon who have more than two types of capabilities
df[df['types_cleaned'].apply(lambda x: len(x) > 2)]
# Out:
# Empty DataFrame
# Columns: [id, num, name, img, height, weight, candy, candy_count, egg, spawn_chance, avg_spawns, spawn_time, multipliers, next_evolution, prev_evolution, weakness_cleaned, types_cleaned]
# Index: []
