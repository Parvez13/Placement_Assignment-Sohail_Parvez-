# %%
import pandas as pd

# %%
df = pd.read_csv('question4_data.csv')

# %%
# Get all the Earth meteorites that fell before the year 2000
df[df['Year at which Earth Meteorite was hit'] < '2000']
# Out:
#     Name of Earth Meteorite  ID of Earth Meteorite nametype     recclass
# 0                    Aachen                      1    Valid           L5  \
# 1                    Aarhus                      2    Valid           H6
# 2                      Abee                      6    Valid          EH4
# 3                  Acapulco                     10    Valid  Acapulcoite
# 4                   Achiras                    370    Valid           L6
# ..                      ...                    ...      ...          ...
# 994                Timochin                  24004    Valid           H5
# 995                Tirupati                  24009    Valid           H6
# 997                   Tjabe                  24011    Valid           H6
# 998                Tjerebon                  24012    Valid           L5
# 999               Tomakovka                  24019    Valid          LL6
#
#      Mass of Earth Meteorite Year at which Earth Meteorite was hit    reclat
# ...

# %%
#  Get all the earth meteorites co-ordinates who fell before the year 1970
year_1970 = df[df['Year at which Earth Meteorite was hit']< '1970']

# %%
year_1970[['Name of Earth Meteorite','Year at which Earth Meteorite was hit']]
# Out:
#     Name of Earth Meteorite Year at which Earth Meteorite was hit
# 0                    Aachen               1880-01-01T00:00:00.000
# 1                    Aarhus               1951-01-01T00:00:00.000
# 2                      Abee               1952-01-01T00:00:00.000
# 4                   Achiras               1902-01-01T00:00:00.000
# 5                  Adhi Kot               1919-01-01T00:00:00.000
# ..                      ...                                   ...
# 994                Timochin               1807-01-01T00:00:00.000
# 995                Tirupati               1934-01-01T00:00:00.000
# 997                   Tjabe               1869-01-01T00:00:00.000
# 998                Tjerebon               1922-01-01T00:00:00.000
# 999               Tomakovka               1905-01-01T00:00:00.000
#
# [780 rows x 2 columns]

# %%
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg
df[df['Mass of Earth Meteorite'] > 10000]
# Out:
#     Name of Earth Meteorite  ID of Earth Meteorite nametype   recclass
# 2                      Abee                      6    Valid        EH4  \
# 7                      Agen                    392    Valid         H5
# 11                      Aïr                    424    Valid         L6
# 16                  Akyumak                    433    Valid  Iron, IVA
# 27               Alfianello                    466    Valid         L6
# ..                      ...                    ...      ...        ...
# 991               Tieschitz                  23989    Valid     H/L3.6
# 992                  Tilden                  23998    Valid         L6
# 994                Timochin                  24004    Valid         H5
# 997                   Tjabe                  24011    Valid         H6
# 998                Tjerebon                  24012    Valid         L5
#
#      Mass of Earth Meteorite Year at which Earth Meteorite was hit    reclat
# ...
